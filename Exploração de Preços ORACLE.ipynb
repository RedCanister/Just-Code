# %% [markdown]
# <a href="https://colab.research.google.com/github/RedCanister/Just-Code/blob/main/Explora%C3%A7%C3%A3o%20de%20Pre%C3%A7os%20ORACLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploração dos preços das licenças da Oracle
# Olá, sejam todos bem-vindxs, sou Jorge Kayodê, estudante de Sistemas para Internet no 4º semestre, e estou trazendo para vocês um trabalho que fiz tratando e visualizando os dados de uma tabela de preços com todas as licenças da Oracle, com os preços atualizados pela última vez em Setembro de 2021, então, bem atualizados. Espero que esse notebook possa te ajudar quando tiver que realizar procedimentos enquanto estuda Ciência de Dados, a área que em que eu quero formar uma carreira.

# %% [markdown]
# ## Motivação:
# Decidi realizar esse projeto depois de ter que fazer um trabalho onde pesquisamos e fizemos uma apresentação sobre Sistemas de Gerenciamento de Banco de dados, ou SGBDs, e fiquei responsável pelo Oracle, junto de Olenice Fátima, colega de sala. Durante as pesquisas, encontramos uma tabela de preços com todas as licenças da Oracle, e foi aí que decidi fazer um trabalho sobre esses dados, e trazê-los para a turma desfrutar de uma apresentação robusta sobre a Oracle, mas no fim, não pude fazer isso a tempo da apresentação, então fomos com o básico, e agora estou trazendo essas informações para que você, estudante de Ti aleatórix, possa saber sobre as licenças dessa empresa que está presente em tantos negócios no mundo todo.

# %% [markdown]
# ## Estrutura do Projeto:
# Nesse notebook do Google Colaboratory, você vai encontrar todo o código que usei para realizar esse trabalho, também com as referências que eu me lembrei de guardar 🤓, na seguinte ordem:
#
#
# 1.   Extração dos Dados do Dataset para o DataFrame Pandas
# 2.   Transformação e formatação do DataFrame no objeto de análise
# 3.   Exploração dos Dados em pandaSQL
# 4.   [Planejado] Visualização dos Dados
#
# Isso por que estamos seguindo o processo ETL, bem conhecido na área de Business Intelligence como Extract, Transform, and Load, ou Extrair, Transformar e Carregar. Extraímos os dados de uma fonte, transformamos os mesmos em um formato que vamos utilizar e os carregamos para uma aplicação para que seja utilizado, nesse caso, um dashboard que ainda vou aprender a fazer, seja no Tableau, ou no Power BI.

# %%
# !pip install pandasql -U
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=f7d5534b432196d2139b4ebf911793a0f1f725f6e9ad829274871be40c2fad1b
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...

# %% [markdown]
# ## Extraindo o Dataset
#
# Esta etapa de extração da tabela foi complicada, e provavelmente poderia ser melhorada com um refinamento dos parâmetros que ainda parece ser meio complexo pra mim, 27% dos dados foram perdidos no momento da conversão das tabelas do arquivo em pdf para um arquivo excel. Eu usei uma ferramenta da Adobe para realizar a conversão e então extrair os dados para realizar essa análise, com o resultado sendo o que verão agora. Conseguindo uma versão mais íntegra dessa tabela, muitos dos procedimentos desse notebook se tornariam irrelevantes, mas deixo aqui para que saibam o que fazer na pior das situações.

# %% [markdown]
# Referências:
#
# https://pandas.pydata.org/pandas-docs/stable/index.html
#
# https://stackoverflow.com/questions/20937538/how-to-display-pandas-dataframe-of-floats-using-a-format-string-for-columns

# %%
# Estaremos utilizando essa duas bilbiotecas, Pandas, a mais popular biblioteca 
#de Ciência de Dados no Python, e pandasql, que traz consultas em SQL para cada projeto
# e matplotlib é um biblioteca de visualização de dados
import pandas as pd
from pandasql import sqldf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Nessa linha vamos alterar a formatação de todos os valores float desse notebook,
#assim adicionando uma cifra e limitando o valor a duas casas decimais
pd.options.display.float_format = 'R${:,.2f}'.format

# %%
# Aqui estamos conjurando o dataset que vamos utilizar a partir de um arquivo
#que está salvo no meu drive, mas o mesmo pode ser feito a partir de um link
file = "/content/drive/MyDrive/Colab Notebooks/Exploração Oracle/precosOracle.xlsx"
url = "https://docs.google.com/spreadsheets/d/1jqS2gpZL_HibEDuPJRuHZK5gefm3UNAh/edit?usp=sharing&ouid=106189476960706264778&rtpof=true&sd=true"
precosOracle = pd.read_excel(file)

# %% [markdown]
# Observando o dataset abaixo, podemos ver que no momento ele está inoperável, sendo até difícil realizar as consultas mais básicas que temos. Algumas colunas que deveriam estar separadas se convergeram, e ainda foram criadas duas colunas vazias que não da pra dizer o que deveria ser, sem contar também com as colunas que sequer foram criadas, mas felizmente, vamos jogar tudo isso fora. Devo ressaltar que nesse projeto, o foco da análise será os preços das licenças, não considerando se é uma licença de 12 meses, ou um só, e nem para qual negócio ou qual licença seria a melhor escolha, estamos apenas compreendendo a distribuição dos preços, e quais relações entre eles podemos encontrar aqui.
#
# Referência:
# https://www.adobe.com/br/acrobat/online/convert-pdf.html
#
# https://betterprogramming.pub/convert-tables-from-pdfs-to-pandas-with-python-d74f8ac31dc2

# %%
precosOracle
# Out:
#      Moeda Mese  Forma de Distribuição                       Família  \
# 0     Real         Licença de Programa      On Premises - Technology
# 1     Real     12  Licença de Programa      On Premises - Technology
# 2     Real     12  Licença de Programa      On Premises - Technology
# 3     Real         Licença de Programa      On Premises - Technology
# 4     Real     12  Licença de Programa      On Premises - Technology
# ...    ...                         ...                           ...
# 6094  Real                      R$1.00  Outros serviços - Technology
# 6095  Real                      R$1.00  Outros serviços - Technology
# 6096  Real                      R$1.00  Outros serviços - Technology
# 6097  Real                      R$1.00  Outros serviços - Technology
# 6098  Real                      R$1.00  Outros serviços - Technology
#
#                                  Contra Nome do Produto Unnamed: 4  \
# 0     7626  Oracle Database Enterprise Edition - Pro...        NaN
# ...

# %%
# Aqui excluímos todas as outras colunas menos o preço e o tipo de licença, nos quais vamos
#trabalhar a visualização dos dados
precosDF = precosOracle.drop(columns = ['Moeda', 'Mese  Forma de Distribuição', 'Família', 
                     'Contra Nome do Produto', 'Unnamed: 4', 'Part Number',
                     'Unnamed: 6'], axis = 1)
precosDF
# Out:
#                        Preço            Tipo de Licença
# 0                 285.157,18  Permanente sem Manutenção
# 1                  61.538,41     Manutenção na Vigência
# 2                  11.795,04                    Suporte
# 3                 138.075,47  Permanente sem Manutenção
# 4                  29.797,41     Manutenção na Vigência
# ...                      ...                        ...
# 6094   60.033,01  Assinatura                        NaN
# 6095              Assinatura                        NaN
# 6096  180.099,03  Assinatura                        NaN
# 6097    1,219237  Assinatura                        NaN
# 6098    0,552305  Assinatura                        NaN
#
# [6099 rows x 2 columns]

# %% [markdown]
# ##Tratamento dos Dados

# %% [markdown]
# Apenas os 17 primeiros itens da lista foram divididos corretamente, o resto, está com erro de dados concentrado na coluna de 'Preços'. Tendo feito a divisão dessa coluna, temos um objeto onde na mesma linha, encontramos um Pandas Series, com o preço na posição [0], e o tipo de licença na posição [1] (após a divisão da string com a função do Python), os dois únicos itens úteis para essa análise.

# %%
# A maior parte dos itens estão com duas colunas juntas em uma, na coluna de preço, que separamos nesse
#bloco, mas ainda precisamos remanejar os tipos de licença para sua própria coluna, com o parâmetro expand=True

precoSplit = precosDF['Preço'].str.split(" ", 1, expand=True)
precoSplit
# Out:
#                0            1
# 0     285.157,18         None
# 1      61.538,41         None
# 2      11.795,04         None
# 3     138.075,47         None
# 4      29.797,41         None
# ...          ...          ...
# 6094   60.033,01   Assinatura
# 6095  Assinatura         None
# 6096  180.099,03   Assinatura
# 6097    1,219237   Assinatura
# 6098    0,552305   Assinatura
#
# [6099 rows x 2 columns]

# %% [markdown]
# ### 6099 originais
# -----
# 4464 restantes
#
# O que equivale a 73,19% sendo usado na análise comparada ao original, levando em consideração os seguintes fatos: A tabela original estava no formato PDF.  Existem outras ferramentas como a biblioteca Camelot e Tabula, que poderiam ajudar com esse procedimento, mas que ainda requeriram um nível de parametrização que eu não pude trazer para esse projeto.

# %%
#Realizando o tratamento do dataset, excluindo linhas vazias e renomeando as colunas
precoClean = precoSplit.dropna()
precoClean = precoClean.reset_index()
precoClean = precoClean.drop(columns=['index'])
precoClean.columns = ['preco', 'tipo_licenca']

# %%
# Convertendo (a hilária) coluna de preços de string para float. A operação desse bloco de código foi feito
#inplace, ou seja, sem gerar uma nova variável, então esse bloco poderá ser executado uma única vez, ou
#com a criação de uma nova variável e DataFrame.

# Esse passo foi necessário por que a função .split() do Python sempre retorna 2 ou mais strings
precoClean['preco'] = [x.replace('.', '') for x in precoClean['preco']]
precoClean['preco'] = precoClean['preco'].apply(lambda x: float(x.split()[0].replace(',', '.')))
precoClean
# Out:
#             preco tipo_licenca
# 0     R$61,538.41   manutencao
# 1     R$11,795.04      suporte
# 2     R$34,819.78   permanente
# 3      R$7,514.29   manutencao
# 4      R$1,440.26      suporte
# ...           ...          ...
# 4459   R$7,504.13   assinatura
# 4460  R$60,033.01   assinatura
# 4461 R$180,099.03   assinatura
# 4462       R$1.22   assinatura
# 4463       R$0.55   assinatura
#
# [4464 rows x 2 columns]

# %%
#Fazendo o mesmo para os tipos de licença, retirando os espaços em branco das variáveis
precoClean['tipo_licenca'] = [x.replace('Manutenção na Vigência', 'manutencao') for x in precoClean['tipo_licenca']]
precoClean['tipo_licenca'] = [x.replace('Permanente sem Manutenção', 'permanente') for x in precoClean['tipo_licenca']]
precoClean['tipo_licenca'] = [x.replace('Suporte', 'suporte') for x in precoClean['tipo_licenca']]
precoClean['tipo_licenca'] = [x.replace('Assinatura', 'assinatura') for x in precoClean['tipo_licenca']]

# Até eu descobrir que não havia removido o espaço em branco, apenas reduzido a label dos tipos de licença
# Mais sobre isso abaixo

# %% [markdown]
# ### Lição de formatação de Dataframes
# Antes de começar a realizar consultas ou sei lá o que mais no conjunto de dados no qual estiver trabalhando, certifique-se de que os mesmos estão prontos para ser consultados, como, saiba em qual tipo estão os dados, e se eles tem algum artefato escondido no seu texto, como whitespace que pode atrapalhar suas consultas.
#
# Referência:
# https://www.roelpeters.be/how-to-remove-trailing-whitespaces-from-column-headers-in-pandas/

# %%
# Uma compreensão de lista do DF (único ao Python) utilizado para encontrar qualquer 
#linha na coluna 'tipo_licenca' que possa ter whitespace no início ou no final da string 
[x for x in precoClean['tipo_licenca'] if x.endswith(' ') or x.startswith(' ')]
# Out:
# []

# %%
# E a função para limpar as strings dessa coluna
precoClean['tipo_licenca'] = precoClean['tipo_licenca'].str.strip()

# %%
precoClean
# Out:
#             preco tipo_licenca
# 0     R$61,538.41   manutencao
# 1     R$11,795.04      suporte
# 2     R$34,819.78   permanente
# 3      R$7,514.29   manutencao
# 4      R$1,440.26      suporte
# ...           ...          ...
# 4459   R$7,504.13   assinatura
# 4460  R$60,033.01   assinatura
# 4461 R$180,099.03   assinatura
# 4462       R$1.22   assinatura
# 4463       R$0.55   assinatura
#
# [4464 rows x 2 columns]

# %% [markdown]
# ## Exploração dos dados com SQL
# Todas as consultas feitas nesse notebook são realizadas através de SQL com o uso da biblioteca pandasql, que traz a sintaxe da linguagem de query para o Python.
#
# Referência:
# https://pypi.org/project/pandasql/

# %% [markdown]
# ### Dados gerais do conjunto de dados
# A partir daqui, faremos a exploração do DataFrame com SQL, construindo tabelas de acordo com cada Tipo de Licença que podemos encontrar:
#
# 1.   Permanente sem Manutenção
# 2.   Manutenção na Vigência
# 3.   Suporte
# 4.   Assinatura

# %%
# describe() é uma função do pandas que pode rapidamente demonstrar todas as características
#estatísticas do DataFrame selecionado. Observar que a contagem dessa função, por ser float
#também foi formatada como um preço
precoClean.describe()
# Out:
#                 preco
# count      R$4,464.00
# mean      R$53,498.91
# std      R$250,675.20
# min            R$0.00
# 25%          R$126.65
# 50%        R$1,339.40
# 75%       R$20,715.36
# max   R$10,721,895.73

# %%
# É com essa função anônima que vamos realizar os queries em SQL em cima do Dataframe, para não ter que escrever a função completa toda vez que for chamada 
pysqldf = lambda q: sqldf(q, globals())

# %%
# Consultando quantos itens temos para cada tipo de licença
q = """
    SELECT tipo_licenca, COUNT(*) as Total
    FROM precoClean
    GROUP BY tipo_licenca
    HAVING COUNT(*)
    """

precoTotalItem = pysqldf(q)
precoTotalItem
# Out:
#   tipo_licenca  Total
# 0   assinatura    849
# 1   manutencao   1206
# 2   permanente   1204
# 3      suporte   1205

# %%
# Consultando qual o valor total para cada tipo de licença
q = """
    SELECT tipo_licenca, SUM(preco) as Total
    FROM precoClean
    GROUP BY tipo_licenca
    """

precoTotalValor = pysqldf(q)
precoTotalValor
# Out:
#   tipo_licenca            Total
# 0   assinatura  R$65,810,203.68
# 1   manutencao  R$29,792,000.36
# 2   permanente R$137,409,785.39
# 3      suporte   R$5,807,166.02

# %%
# Aqui observamos a média para cada tipo de licença
precoMediaA = precoTotalValor['Total'][0] / precoTotalItem['Total'][0]
precoMediaM = precoTotalValor['Total'][1] / precoTotalItem['Total'][1]
precoMediaP = precoTotalValor['Total'][2] / precoTotalItem['Total'][2]
precoMediaS = precoTotalValor['Total'][3] / precoTotalItem['Total'][3]

print('Preço médio das licenças permanentes: R$%.3f' % (precoMediaP))
print('Preço médio das licenças de manutenção: R$%.3f' % (precoMediaM))
print('Preço médio das licenças de suporte: R$%.3f' % (precoMediaS))
print('Preço médio das licenças assinaturas: R$%.3f' % (precoMediaA))
# Out:
# Preço médio das licenças permanentes: R$114127.729
# Preço médio das licenças de manutenção: R$24703.151
# Preço médio das licenças de suporte: R$4819.225
# Preço médio das licenças assinaturas: R$77514.963

# %% [markdown]
# Aqui realizamos a consulta para separarmos todas as licenças desse tipo específico, o que repetiremos para todos os outros tipos de licença. E para cada tipo de licença, selecionamos os 7 maiores e menores itens da lista de acordo com seu preço, e realizamos uma última consulta no final, com amostras aleatórias para cada tipo de licença, realizando assim a tão esperada exploração dos preços das licenças da Oracle.

# %% [markdown]
# ### Tipo de licença Permanente sem Manutenção

# %%
q = """
    SELECT preco, tipo_licenca FROM precoClean
    WHERE tipo_licenca = 'permanente'
    """

precoPermanente = pysqldf(q)
precoPermanente.sort_values(by=['preco'], inplace=True)
precoPermanente.reset_index(inplace=True)
precoPermanente.drop(columns=['index'], inplace=True)
precoPermanente
# Out:
#               preco tipo_licenca
# 0            R$1.39   permanente
# 1            R$2.10   permanente
# 2            R$3.00   permanente
# 3            R$4.21   permanente
# 4            R$6.00   permanente
# ...             ...          ...
# 1199 R$2,941,617.53   permanente
# 1200 R$2,941,617.53   permanente
# 1201 R$3,001,650.54   permanente
# 1202 R$3,451,898.88   permanente
# 1203 R$3,451,898.88   permanente
#
# [1204 rows x 2 columns]

# %%
precoPH = precoPermanente['preco'].head(7)
precoPT = precoPermanente['preco'].tail(7)
dados = zip(precoPH, precoPT)

tabelaPermanente = pd.DataFrame(dados, columns=['bot7', 'top7'])
tabelaPermanente
# Out:
#     bot7           top7
# 0 R$1.39 R$2,491,370.70
# 1 R$2.10 R$2,761,518.50
# 2 R$3.00 R$2,941,617.53
# 3 R$4.21 R$2,941,617.53
# 4 R$6.00 R$3,001,650.54
# 5 R$6.00 R$3,451,898.88
# 6 R$6.00 R$3,451,898.88

# %%
precoPermanente.sample(10, random_state=0)
# Out:
#             preco tipo_licenca
# 486    R$2,101.10   permanente
# 5          R$6.00   permanente
# 438    R$1,800.95   permanente
# 271      R$840.14   permanente
# 966  R$138,075.47   permanente
# 783   R$17,409.14   permanente
# 268      R$751.15   permanente
# 395    R$1,470.62   permanente
# 478    R$2,101.10   permanente
# 1012 R$210,116.29   permanente

# %% [markdown]
# ### Tipo de licença Manutenção na Vigência

# %%
q = """
    SELECT preco, tipo_licenca FROM precoClean
    WHERE tipo_licenca = 'manutencao'
    """

precoManutencao = pysqldf(q)
precoManutencao.sort_values(by=['preco'], inplace=True)
precoManutencao.reset_index(inplace=True)
precoManutencao.drop(columns=['index'], inplace=True)
precoManutencao
# Out:
#             preco tipo_licenca
# 0          R$0.30   manutencao
# 1          R$0.45   manutencao
# 2          R$0.65   manutencao
# 3          R$0.91   manutencao
# 4          R$1.30   manutencao
# ...           ...          ...
# 1201 R$634,816.49   manutencao
# 1202 R$634,816.49   manutencao
# 1203 R$647,771.93   manutencao
# 1204 R$744,937.88   manutencao
# 1205 R$744,937.88   manutencao
#
# [1206 rows x 2 columns]

# %%
precoMH = precoManutencao['preco'].head(7)
precoMT = precoManutencao['preco'].tail(7)
dados = zip(precoMH, precoMT)

tabelaManutencao = pd.DataFrame(dados, columns=['bot7', 'top7'])
tabelaManutencao
# Out:
#     bot7         top7
# 0 R$0.30 R$537,650.86
# 1 R$0.45 R$595,950.17
# 2 R$0.65 R$634,816.49
# 3 R$0.91 R$634,816.49
# 4 R$1.30 R$647,771.93
# 5 R$1.30 R$744,937.88
# 6 R$1.30 R$744,937.88

# %%
precoManutencao.sample(10, random_state=0)
# Out:
#            preco tipo_licenca
# 395     R$323.88   manutencao
# 5         R$1.30   manutencao
# 141      R$71.29   manutencao
# 452     R$414.69   manutencao
# 52        R$1.30   manutencao
# 1085 R$59,595.15   manutencao
# 328     R$259.10   manutencao
# 890  R$15,546.46   manutencao
# 319     R$239.57   manutencao
# 269     R$162.10   manutencao

# %% [markdown]
# ### Tipo de licença Suporte

# %%
q = """
    SELECT preco, tipo_licenca FROM precoClean
    WHERE tipo_licenca = 'suporte'
    """

precoSuporte = pysqldf(q)
precoSuporte.sort_values(by=['preco'], inplace=True)
precoSuporte.reset_index(inplace=True)
precoSuporte.drop(columns=['index'], inplace=True)
precoSuporte
# Out:
#             preco tipo_licenca
# 0          R$0.06      suporte
# 1          R$0.09      suporte
# 2          R$0.12      suporte
# 3          R$0.17      suporte
# 4          R$0.25      suporte
# ...           ...          ...
# 1200 R$121,675.00      suporte
# 1201 R$121,675.00      suporte
# 1202 R$124,158.16      suporte
# 1203 R$142,781.91      suporte
# 1204 R$142,781.91      suporte
#
# [1205 rows x 2 columns]

# %%
precoSH = precoSuporte['preco'].head(7)
precoST = precoSuporte['preco'].tail(7)
dados = zip(precoSH, precoST)

tabelaSuporte = pd.DataFrame(dados, columns=['bot7', 'top7'])
tabelaSuporte
# Out:
#     bot7         top7
# 0 R$0.06 R$103,051.30
# 1 R$0.09 R$114,225.51
# 2 R$0.12 R$121,675.00
# 3 R$0.17 R$121,675.00
# 4 R$0.25 R$124,158.16
# 5 R$0.25 R$142,781.91
# 6 R$0.25 R$142,781.91

# %%
precoSuporte.sample(10, random_state=2)
# Out:
#            preco tipo_licenca
# 680     R$285.56      suporte
# 615     R$142.81      suporte
# 61        R$0.25      suporte
# 824   R$1,141.04      suporte
# 68        R$0.25      suporte
# 922   R$4,345.55      suporte
# 1096 R$13,036.59      suporte
# 780     R$694.02      suporte
# 888   R$2,855.63      suporte
# 692     R$285.56      suporte

# %% [markdown]
# ### Tipo de licença Assinatura

# %%
q = """
    SELECT preco, tipo_licenca FROM precoClean
    WHERE tipo_licenca = 'assinatura'
    """

precoAssinatura = pysqldf(q)
precoAssinatura.sort_values(by=['preco'], inplace=True)
precoAssinatura.reset_index(inplace=True)
precoAssinatura.drop(columns=['index'], inplace=True)
precoAssinatura
# Out:
#               preco tipo_licenca
# 0            R$0.00   assinatura
# 1            R$0.00   assinatura
# 2            R$0.00   assinatura
# 3            R$0.00   assinatura
# 4            R$0.00   assinatura
# ..              ...          ...
# 844  R$1,440,792.26   assinatura
# 845  R$1,560,858.28   assinatura
# 846  R$1,680,924.30   assinatura
# 847  R$1,800,990.32   assinatura
# 848 R$10,721,895.73   assinatura
#
# [849 rows x 2 columns]

# %%
# Como nesse tipo de licença descobrimos que há itens que são de graça, os últimos
# são todos zeros, mas considerando que mesmo assim não difere muito dos outros tipos de licença
precoAH = precoAssinatura['preco'].head(7)
precoAT = precoAssinatura['preco'].tail(7)
dados = zip(precoAH, precoAT)

tabelaAssinatura = pd.DataFrame(dados, columns=['bot7', 'top7'])
tabelaAssinatura
# Out:
#     bot7            top7
# 0 R$0.00  R$1,368,752.65
# 1 R$0.00  R$1,404,772.45
# 2 R$0.00  R$1,440,792.26
# 3 R$0.00  R$1,560,858.28
# 4 R$0.00  R$1,680,924.30
# 5 R$0.00  R$1,800,990.32
# 6 R$0.00 R$10,721,895.73

# %%
precoAssinatura.sample(10, random_state=0)
# Out:
#           preco tipo_licenca
# 214    R$150.08   assinatura
# 293    R$600.33   assinatura
# 241    R$240.13   assinatura
# 193     R$86.45   assinatura
# 162     R$30.02   assinatura
# 55       R$0.40   assinatura
# 175     R$42.48   assinatura
# 247    R$300.17   assinatura
# 460 R$12,006.60   assinatura
# 392  R$3,001.65   assinatura

# %% [markdown]
# ## Visualização de dados
#
# A ser planejado
